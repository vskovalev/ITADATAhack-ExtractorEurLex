# %%
import json 
import pandas as pd

# %%
pp = ['2', '4']
kk = []

with open('./files/txts/celex_to_text_part_0.txt', encoding="utf8") as file:
    for celex in file:
        try:
            kk.append(celex.split(':')[0].split('_')[1])
        except:
            print(celex.split(':')[0])
            pass

with open(f'./files/txts/celex_to_text_part_1.txt', encoding="utf8") as file:
    for celex in file:
        try:
            kk.append(celex.split(':')[0].split('_')[1])
        except:
            print(celex.split(':')[0])
            pass

with open(f'./files/txts/celex_to_text_part_5.txt', encoding="utf8") as file:
    for celex in file:
        try:
            kk.append(celex.split(':')[0].split('_')[1])
        except:
            print(celex.split(':')[0])
            pass

with open(f'./files/txts/celex_to_text_part_10.txt', encoding="utf8") as file:
    for celex in file:
        try:
            kk.append(celex.split(':')[0].split('_')[1])
        except:
            print(celex.split(':')[0])
            pass
# Out:
# }
#
#
#
# }
#
# }
#
# }

# %%
pd.DataFrame(set(kk)).to_csv('list_of_celexes.csv')

# %%
from functions.functions_os.kill_chrome_processes import kill_chrome_processes

# %%
kill_chrome_processes()

# %%
pd.read_csv('list_of_celexes.csv')
# Out:
#        Unnamed: 0                    0
# 0               0           22022D1595
# 1               1           31991D0088
# 2               2      32014O0031R(01)
# 3               3           32008R0365
# 4               4           32003R0257
# ...           ...                  ...
# 16385       16385           31991R3307
# 16386       16386  02006L0126-20201101
# 16387       16387           31971D0238
# 16388       16388           31982D0305
# 16389       16389  32005D0012(01)R(01)
#
# [16390 rows x 2 columns]

# %%
with open(f'./files/txts/celex_to_text_part_4.txt', encoding="utf8") as file:
    for celex in file:
        try:
            kk.append(celex.split(':')[0].split('_')[1])
        except:
            print(celex.split(':')[0])
            pass
# Out:
# }

# %%
with open(f'./files/txts/celex_to_text_part_2.txt', encoding="utf32") as file:
    ff = file.read()

# %%
with open(f'./files/txts/celex_to_text_part_0.txt', encoding="utf8", mode='x') as file:
    print(ff, file=file)

# %%
kk_ = set(kk)

# %%
import pandas as pd

# %%
set(pd.read_csv('list_of_celexes.csv')['0'].to_list())
# Out:
# {'22022D1595',
#  '31991D0088',
#  '32014O0031R(01)',
#  '32008R0365',
#  '32003R0257',
#  '32013R1308R(17)',
#  '32021D2316',
#  '32020L0432',
#  '32003B0413',
#  '32021D2199',
#  '32013L0036R(06)',
#  '32008R1045',
#  '32003D0757R(01)',
#  '22020D0223',
#  '32014L0049R(01)',
#  '32014R0540',
#  '32015R0151',
#  '32019R1686',
#  '32008L0009',
#  '32009H0120',
#  '31976A0470',
#  '02011R0282-20220701',
#  '32021R0880',
#  '02006L0042-20190726',
#  '31990D0212',
#  '32008R0420',
#  '01999D0187-20021018',
#  '02008R0767-20230803',
#  '22007A1221(03)',
#  '32020R2104',
#  '32021D1845',
#  '32019R0247',
#  '31977R2687',
#  '22022D1030',
#  '32014L0049R(02)',
#  '31994R3330',
#  '32019R2074',
#  '32008L0117',
#  '32020D1368',
#  '32014D0309',
#  '32008R0402',
#  '32019R0694',
#  '32014R0826',
#  '32021D1984',
#  '01990D0185-20121221',
#  '32007R1355',
#  '32005R0117',
#  '32021D2267',
#  '32008R0180',
#  '32009D0400',
#  '32014R0799',
#  '32006R1281',
#  '32014L0065R(07)',
# ...

# %%
with open('list_of_celexes.csv', 'r') as file:
    ff = file.read()

# %%
pd.DataFrame(kk_).to_csv('list_of_celexes.csv')

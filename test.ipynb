# %%
from algorighms.functions_treatment.function_pdf_to_txt \
    import function_pdf_to_txt

# %%
function_pdf_to_txt(part='10')
# Out:
# Save
# 100%|██████████| 1148/1148 [16:07<00:00,  1.19it/s]
# Remove
# 100%|█████████▉| 1143/1145 [00:01<00:00, 579.32it/s]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 function_pdf_to_txt(part='10')
#
# File c:\Users\vkovalev\Desktop\New folder (2)\algorighms\functions_treatment\function_pdf_to_txt.py:36, in function_pdf_to_txt(part)
#      34 for name in tqdm(list_of_pdf_names_removed):
#      35     path_for_pdf = f'./files/pdfs/{name}'
# ---> 36     os.remove(path_for_pdf)
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: './files/pdfs/CELEX_42014X0822(02)_IT_TXT.pdf'

# %%
list_of_lists = []
with open('files/txts/celex_ids.txt') as f:
    for line in f:
        inner_list = [elt.replace("'", '').strip() for elt in line.split(',')]
        list_of_lists.extend(inner_list)

# %%
list_of_lists
# Out:
# ['CELEX_01980A1118(01)-20131029_BG_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_CS_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_DA_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_DE_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_EL_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_EN_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_ES_TXT.pdf',
#  'CELEX_01980A1118(01)-20131029_ET_TXT.pdf',
#  'CELEX_01992L0085-20190726_BG_TXT.pdf',
#  'CELEX_01992L0085-20190726_CS_TXT.pdf',
#  'CELEX_01992L0085-20190726_DA_TXT.pdf',
#  'CELEX_01992L0085-20190726_DE_TXT.pdf',
#  'CELEX_01992L0085-20190726_EL_TXT.pdf',
#  'CELEX_01992L0085-20190726_EN_TXT.pdf',
#  'CELEX_01992L0085-20190726_ES_TXT.pdf',
#  'CELEX_01992L0085-20190726_ET_TXT.pdf',
#  'CELEX_01992L0085-20190726_FI_TXT.pdf',
#  'CELEX_01992L0085-20190726_FR_TXT.pdf',
#  'CELEX_01992L0085-20190726_HR_TXT.pdf',
#  'CELEX_01992L0085-20190726_HU_TXT.pdf',
#  'CELEX_01992L0085-20190726_IT_TXT.pdf',
#  'CELEX_01992L0085-20190726_LT_TXT.pdf',
# ...

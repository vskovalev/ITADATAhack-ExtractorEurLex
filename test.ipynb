# %%
from selenium_walker.get_celexes import get_list_of_celexes, get_seria_of_celexes

# %%
get_list_of_celexes()
# Out:
# [['31975Y0128(01)',
#   '32009D0604',
#   '32010D0029',
#   '32012R0577',
#   '02002D0620-20020726',
#   '31995Y0228',
#   '32011D1011',
#   '32005B0550',
#   '32014D0049(01)',
#   '32008R1104',
#   'CONFIDENTIEL',
#   '32005D0820',
#   '32023D0898',
#   '31984Y1019',
#   '31971R2654',
#   '32006R1986',
#   '31985R3519',
#   '32006R0957R',
#   '32015R0389',
#   '32023D1539',
#   '31999D0307R',
#   '42021D0928R',
#   '31993R2551',
#   '32021D0512',
#   '32009D0307',
#   '32010D0010',
#   '31980R0160',
#   '32012Q0929(01)R(03)',
#   '31998R2532R(01)',
#   '32012R0154',
#   '31999D0005(01)',
#   '32011R0315',
#   '31991R3798',
#   '6631995D0406(01)',
#   '31997R0288',
#   '32007D0883',
#   '31968R0259(02)R(02)',
#   '32011R1174',
#   '32020R2093R(02)',
#   '32019R0452R',
#   '32006R1922',
#   '32021D1282',
#   '32005D0012(01)',
#   '31971R1182',
#   '32004D0002R',
#   '32021D2040',
#   '31958R0001',
#   '32007R0438',
#   '02013R1003',
#   '32010D1020',
#   '32004D0452R',
# ...

# %%
get_seria_of_celexes()
# Out:
#                   CELEX_ID  Directory code
# 0           31975Y0128(01)               1
# 1               32009D0604               1
# 2               32010D0029               1
# 3               32012R0577               1
# 4      02002D0620-20020726               1
# ...                    ...             ...
# 29648      32003L0087R(03)              20
# 29649           32014D0773              20
# 29650           32007R0321              20
# 29651           32008R0216              20
# 29652           32011D0432              20
#
# [380227 rows x 2 columns]
